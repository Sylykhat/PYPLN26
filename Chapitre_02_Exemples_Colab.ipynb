# %% [markdown]
# <a href="https://colab.research.google.com/github/Sylykhat/PYPLN26/blob/main/Chapitre_02_Exemples_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Voici un titre **principal**
# ## Ceci est un titre de *deuxième niveau*
# Voici du texte simple.

# %%
print("Bien le bonjour !")
# Out:
# Bien le bonjour !
